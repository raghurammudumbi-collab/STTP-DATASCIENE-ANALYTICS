# %% [markdown]
# <a href="https://colab.research.google.com/github/raghurammudumbi-collab/STTP-DATASCIENE-ANALYTICS/blob/main/STTP_Python_Practise_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This program displays a message on the screen
print("Hello, World!")
# Out:
# Hello, World!

# %%
# Assigning values to variables
num1 = 15
num2 = 25

# Adding the values
total = num1 + num2

# Printing using an f-string
print(f"The sum of {num1} and {num2} is {total}")
# Out:
# The sum of 15 and 25 is 40

# %%
# Checking if a number is even or odd
number = 7

if number % 2 == 0:
    print(f"{number} is an Even number.")
else:
    print(f"{number} is an Odd number.")
# Out:
# 7 is an Odd number.

# %%
# Creating a list of fruits
fruits = ["apple", "banana", "cherry"]

# Looping through each item in the list
for fruit in fruits:
    print(f"I enjoy eating {fruit}s.")
# Out:
# I enjoy eating apples.
# I enjoy eating bananas.
# I enjoy eating cherrys.

# %%
# Defining a function that calculates an area
def calculate_area(width, height):
    return width * height

# Calling the function
result = calculate_area(5, 10)
print(f"The calculated area is: {result}")
# Out:
# The calculated area is: 50

# %%
# Defining a class blueprint
class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def display_info(self):
        return f"This car is a {self.brand} {self.model}."

# %%
# Defining a class blueprint
class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def display_info(self):
        return f"This car is a {self.brand} {self.model}."

# Creating an instance (object) of the class
my_car = Car("Toyota", "Corolla")
print(my_car.display_info())
# Out:
# This car is a Toyota Corolla.
