# %% [markdown]
# <a href="https://colab.research.google.com/github/raghurammudumbi-collab/STTP-DATASCIENE-ANALYTICS/blob/main/STTP_Pandas_Practise_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'London', 'Paris']
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris

# %%
 # View the first 2 rows
print(df.head(2))

# Get summary statistics for numerical columns
print(df.describe())

# Check data types and missing values
print(df.info())
# Out:
#     Name  Age      City
# 0  Alice   25  New York
# 1    Bob   30    London
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# None

# %%
# Filter rows where Age is greater than 28
older_df = df[df['Age'] > 28]
print(older_df)
# Out:
#       Name  Age    City
# 1      Bob   30  London
# 2  Charlie   35   Paris

# %%
# Sample exactly 2 random rows
print(df.sample(n=2))

# Sample 50% of the dataset randomly
print(df.sample(frac=0.5))
# Out:
#       Name  Age    City
# 1      Bob   30  London
# 2  Charlie   35   Paris
#       Name  Age      City
# 0    Alice   25  New York
# 2  Charlie   35     Paris

# %%
import pandas as pd

sales_data = {
    'Region': ['North', 'North', 'South', 'South'],
    'Sales': [250, 300, 150, 200]
}
df_sales = pd.DataFrame(sales_data)

# Calculate total sales by Region
total_sales = df_sales.groupby('Region')['Sales'].sum()
print(total_sales)
# Out:
# Region
# North    550
# South    350
# Name: Sales, dtype: int64

# %%
import numpy as np

# Introduce a missing value
df.loc[0, 'Age'] = np.nan

# Fill missing values with the mean Age
df['Age'] = df['Age'].fillna(df['Age'].mean())
print(df)
# Out:
#       Name   Age      City
# 0    Alice  32.5  New York
# 1      Bob  30.0    London
# 2  Charlie  35.0     Paris
